# %% [markdown]
# <a href="https://colab.research.google.com/github/ZohaAsghar/Student-Performance/blob/main/Student_Performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import os

# %%
import kagglehub
path = kagglehub.dataset_download("devansodariya/student-performance-data")
# Out:
# Downloading to /root/.cache/kagglehub/datasets/devansodariya/student-performance-data/1.archive...
# 100%|██████████| 7.16k/7.16k [00:00<00:00, 5.60MB/s]
# Extracting files...

# %%
df=pd.read_csv(os.path.join(path,"student_data.csv"))

# %%
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0    ...      4        3      4     1     1      3        6   5   6   6
# 1    ...      5        3      3     1     1      3        4   5   5   6
# 2    ...      4        3      2     2     3      3       10   7   8  10
# 3    ...      3        2      2     1     1      5        2  15  14  15
# 4    ...      4        3      2     1     2      5        4   6  10  10
# ..   ...    ...      ...    ...   ...   ...    ...      ...  ..  ..  ..
# 390  ...      5        5      4     4     5      4       11   9   9   9
# 391  ...      2        4      5     3     4      2        3  14  16  16
# 392  ...      5        5      3     3     3      3        3  10   8   7
# 393  ...      4        4      1     3     4      5        0  11  12  10
# 394  ...      3        2      3     3     3      5        5   8   9   9
#
# [395 rows x 33 columns]

# %%
df.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# std      0.896659    0.998862    1.113278    0.890741    1.287897    1.390303
# min      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
# 25%      4.000000    3.000000    2.000000    1.000000    1.000000    3.000000
# 50%      4.000000    3.000000    3.000000    1.000000    2.000000    4.000000
# 75%      5.000000    4.000000    4.000000    2.000000    3.000000    5.000000
# max      5.000000    5.000000    5.000000    5.000000    5.000000    5.000000
#
#          absences          G1          G2          G3
# count  395.000000  395.000000  395.000000  395.000000
# mean     5.708861   10.908861   10.713924   10.415190
# std      8.003096    3.319195    3.761505    4.581443
# min      0.000000    3.000000    0.000000    0.000000
# 25%      0.000000    8.000000    9.000000    8.000000
# 50%      4.000000   11.000000   11.000000   11.000000
# 75%      8.000000   13.000000   13.000000   14.000000
# max     75.000000   19.000000   19.000000   20.000000

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
df.tail()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 390  ...      5        5      4     4     5      4       11   9   9   9
# 391  ...      2        4      5     3     4      2        3  14  16  16
# 392  ...      5        5      3     3     3      3        3  10   8   7
# 393  ...      4        4      1     3     4      5        0  11  12  10
# 394  ...      3        2      3     3     3      5        5   8   9   9
#
# [5 rows x 33 columns]

# %%
df.value_counts()
# Out:
# school  sex  age  address  famsize  Pstatus  Medu  Fedu  Mjob      Fjob      reason      guardian  traveltime  studytime  failures  schoolsup  famsup  paid  activities  nursery  higher  internet  romantic  famrel  freetime  goout  Dalc  Walc  health  absences  G1  G2  G3
# MS      M    21   R        GT3      T        1     1     other     other     course      other     1           1          3         no         no      no    no          no       yes     no        no        5       5         3      3     3     3       3         10  8   7     1
# GP      F    15   R        GT3      T        1     1     at_home   other     home        mother    2           4          1         yes        yes     yes   yes         yes      yes     yes       no        3       1         2      1     1     1       2         7   10  10    1
#                                                          other     other     reputation  mother    1           2          2         yes        yes     no    no          no       yes     yes       yes       3       3         4      2     4     5       2         8   6   5     1
#                                              2     2     at_home   other     reputation  mother    1           1          0         yes        yes     yes   yes         yes      yes     no        no        4       3         1      1     1     2       8         14  13  13    1
#                                                    4     services  health    course      mother    1           3          0         yes        yes     yes   yes         yes      yes     yes       no        4       3         2      1     1     5       2         10  9   8     1
#                                                                                                                                                                                                                                                                                   ..
#                   U        GT3      T        1     2     at_home   services  course      mother    1           2          0         no         no      no    no          no       yes     yes       no        3       2         3      1     2     1       2         16  15  15    1
#                                                                    other     course      mother    1           2          0         no         yes     yes   no          no       yes     yes       no        4       3         2      1     1     5       2         10  11  11    1
#                                                    1     other     services  course      father    1           2          0         no         yes     yes   no          yes      yes     yes       no        4       4         2      1     2     5       0         8   11  11    1
#                                                                    other     home        father    1           2          0         no         yes     no    yes         no       yes     yes       no        4       3         2      2     3     4       2         9   10  10    1
#                                                          at_home   other     course      mother    3           1          0         no         yes     no    yes         no       yes     yes       yes       4       3         3      1     2     4       0         8   0   0     1
# Name: count, Length: 395, dtype: int64

# %%
df.isnull()
# Out:
#      school    sex    age  address  famsize  Pstatus   Medu   Fedu   Mjob  \
# 0     False  False  False    False    False    False  False  False  False
# 1     False  False  False    False    False    False  False  False  False
# 2     False  False  False    False    False    False  False  False  False
# 3     False  False  False    False    False    False  False  False  False
# 4     False  False  False    False    False    False  False  False  False
# ..      ...    ...    ...      ...      ...      ...    ...    ...    ...
# 390   False  False  False    False    False    False  False  False  False
# 391   False  False  False    False    False    False  False  False  False
# 392   False  False  False    False    False    False  False  False  False
# 393   False  False  False    False    False    False  False  False  False
# 394   False  False  False    False    False    False  False  False  False
#
#       Fjob  ...  famrel  freetime  goout   Dalc   Walc  health  absences  \
# 0    False  ...   False     False  False  False  False   False     False
# 1    False  ...   False     False  False  False  False   False     False
# 2    False  ...   False     False  False  False  False   False     False
# 3    False  ...   False     False  False  False  False   False     False
# 4    False  ...   False     False  False  False  False   False     False
# ..     ...  ...     ...       ...    ...    ...    ...     ...       ...
# 390  False  ...   False     False  False  False  False   False     False
# 391  False  ...   False     False  False  False  False   False     False
# 392  False  ...   False     False  False  False  False   False     False
# 393  False  ...   False     False  False  False  False   False     False
# 394  False  ...   False     False  False  False  False   False     False
#
#         G1     G2     G3
# 0    False  False  False
# 1    False  False  False
# 2    False  False  False
# 3    False  False  False
# 4    False  False  False
# ..     ...    ...    ...
# 390  False  False  False
# 391  False  False  False
# 392  False  False  False
# 393  False  False  False
# 394  False  False  False
#
# [395 rows x 33 columns]

# %%
df.fillna(1)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0    ...      4        3      4     1     1      3        6   5   6   6
# 1    ...      5        3      3     1     1      3        4   5   5   6
# 2    ...      4        3      2     2     3      3       10   7   8  10
# 3    ...      3        2      2     1     1      5        2  15  14  15
# 4    ...      4        3      2     1     2      5        4   6  10  10
# ..   ...    ...      ...    ...   ...   ...    ...      ...  ..  ..  ..
# 390  ...      5        5      4     4     5      4       11   9   9   9
# 391  ...      2        4      5     3     4      2        3  14  16  16
# 392  ...      5        5      3     3     3      3        3  10   8   7
# 393  ...      4        4      1     3     4      5        0  11  12  10
# 394  ...      3        2      3     3     3      5        5   8   9   9
#
# [395 rows x 33 columns]

# %%
df["school"].value_counts()
# Out:
# school
# GP    349
# MS     46
# Name: count, dtype: int64

# %%
df["address"].value_counts()
# Out:
# address
# U    307
# R     88
# Name: count, dtype: int64

# %%
df["Fjob"].value_counts()
# Out:
# Fjob
# other       217
# services    111
# teacher      29
# at_home      20
# health       18
# Name: count, dtype: int64

# %%
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0    ...      4        3      4     1     1      3        6   5   6   6
# 1    ...      5        3      3     1     1      3        4   5   5   6
# 2    ...      4        3      2     2     3      3       10   7   8  10
# 3    ...      3        2      2     1     1      5        2  15  14  15
# 4    ...      4        3      2     1     2      5        4   6  10  10
# ..   ...    ...      ...    ...   ...   ...    ...      ...  ..  ..  ..
# 390  ...      5        5      4     4     5      4       11   9   9   9
# 391  ...      2        4      5     3     4      2        3  14  16  16
# 392  ...      5        5      3     3     3      3        3  10   8   7
# 393  ...      4        4      1     3     4      5        0  11  12  10
# 394  ...      3        2      3     3     3      5        5   8   9   9
#
# [395 rows x 33 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
coder=LabelEncoder()

# %%
df["romantic"]=df["romantic"].astype(str)
df["romantic"]=coder.fit_transform(df["romantic"])
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0    ...      4        3      4     1     1      3        6   5   6   6
# 1    ...      5        3      3     1     1      3        4   5   5   6
# 2    ...      4        3      2     2     3      3       10   7   8  10
# 3    ...      3        2      2     1     1      5        2  15  14  15
# 4    ...      4        3      2     1     2      5        4   6  10  10
# ..   ...    ...      ...    ...   ...   ...    ...      ...  ..  ..  ..
# 390  ...      5        5      4     4     5      4       11   9   9   9
# 391  ...      2        4      5     3     4      2        3  14  16  16
# 392  ...      5        5      3     3     3      3        3  10   8   7
# 393  ...      4        4      1     3     4      5        0  11  12  10
# 394  ...      3        2      3     3     3      5        5   8   9   9
#
# [395 rows x 33 columns]

# %%
df["school"]=df["school"].astype(str)
df["school"]=coder.fit_transform(df["school"])
df
# Out:
#      school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0         0   F   18       U     GT3       A     4     4   at_home   teacher
# 1         0   F   17       U     GT3       T     1     1   at_home     other
# 2         0   F   15       U     LE3       T     1     1   at_home     other
# 3         0   F   15       U     GT3       T     4     2    health  services
# 4         0   F   16       U     GT3       T     3     3     other     other
# ..      ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390       1   M   20       U     LE3       A     2     2  services  services
# 391       1   M   17       U     LE3       T     3     1  services  services
# 392       1   M   21       R     GT3       T     1     1     other     other
# 393       1   M   18       R     LE3       T     3     2  services     other
# 394       1   M   19       U     LE3       T     1     1     other   at_home
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0    ...      4        3      4     1     1      3        6   5   6   6
# 1    ...      5        3      3     1     1      3        4   5   5   6
# 2    ...      4        3      2     2     3      3       10   7   8  10
# 3    ...      3        2      2     1     1      5        2  15  14  15
# 4    ...      4        3      2     1     2      5        4   6  10  10
# ..   ...    ...      ...    ...   ...   ...    ...      ...  ..  ..  ..
# 390  ...      5        5      4     4     5      4       11   9   9   9
# 391  ...      2        4      5     3     4      2        3  14  16  16
# 392  ...      5        5      3     3     3      3        3  10   8   7
# 393  ...      4        4      1     3     4      5        0  11  12  10
# 394  ...      3        2      3     3     3      5        5   8   9   9
#
# [395 rows x 33 columns]

# %%
df["sex"]=df["sex"].astype(str)
df["sex"]=coder.fit_transform(df["sex"])
df
# Out:
#      school  sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0         0    0   18       U     GT3       A     4     4   at_home   teacher
# 1         0    0   17       U     GT3       T     1     1   at_home     other
# 2         0    0   15       U     LE3       T     1     1   at_home     other
# 3         0    0   15       U     GT3       T     4     2    health  services
# 4         0    0   16       U     GT3       T     3     3     other     other
# ..      ...  ...  ...     ...     ...     ...   ...   ...       ...       ...
# 390       1    1   20       U     LE3       A     2     2  services  services
# 391       1    1   17       U     LE3       T     3     1  services  services
# 392       1    1   21       R     GT3       T     1     1     other     other
# 393       1    1   18       R     LE3       T     3     2  services     other
# 394       1    1   19       U     LE3       T     1     1     other   at_home
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0    ...      4        3      4     1     1      3        6   5   6   6
# 1    ...      5        3      3     1     1      3        4   5   5   6
# 2    ...      4        3      2     2     3      3       10   7   8  10
# 3    ...      3        2      2     1     1      5        2  15  14  15
# 4    ...      4        3      2     1     2      5        4   6  10  10
# ..   ...    ...      ...    ...   ...   ...    ...      ...  ..  ..  ..
# 390  ...      5        5      4     4     5      4       11   9   9   9
# 391  ...      2        4      5     3     4      2        3  14  16  16
# 392  ...      5        5      3     3     3      3        3  10   8   7
# 393  ...      4        4      1     3     4      5        0  11  12  10
# 394  ...      3        2      3     3     3      5        5   8   9   9
#
# [395 rows x 33 columns]

# %%
df["address"]=df["address"].astype(str)
df["address"]=coder.fit_transform(df["address"])
df
# Out:
#      school  sex  age  address famsize Pstatus  Medu  Fedu      Mjob  \
# 0         0    0   18        1     GT3       A     4     4   at_home
# 1         0    0   17        1     GT3       T     1     1   at_home
# 2         0    0   15        1     LE3       T     1     1   at_home
# 3         0    0   15        1     GT3       T     4     2    health
# 4         0    0   16        1     GT3       T     3     3     other
# ..      ...  ...  ...      ...     ...     ...   ...   ...       ...
# 390       1    1   20        1     LE3       A     2     2  services
# 391       1    1   17        1     LE3       T     3     1  services
# 392       1    1   21        0     GT3       T     1     1     other
# 393       1    1   18        0     LE3       T     3     2  services
# 394       1    1   19        1     LE3       T     1     1     other
#
#          Fjob  ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  \
# 0     teacher  ...      4        3      4     1     1      3        6   5   6
# 1       other  ...      5        3      3     1     1      3        4   5   5
# 2       other  ...      4        3      2     2     3      3       10   7   8
# 3    services  ...      3        2      2     1     1      5        2  15  14
# 4       other  ...      4        3      2     1     2      5        4   6  10
# ..        ...  ...    ...      ...    ...   ...   ...    ...      ...  ..  ..
# 390  services  ...      5        5      4     4     5      4       11   9   9
# 391  services  ...      2        4      5     3     4      2        3  14  16
# 392     other  ...      5        5      3     3     3      3        3  10   8
# 393     other  ...      4        4      1     3     4      5        0  11  12
# 394   at_home  ...      3        2      3     3     3      5        5   8   9
#
#      G3
# 0     6
# 1     6
# 2    10
# 3    15
# 4    10
# ..   ..
# 390   9
# 391  16
# 392   7
# 393  10
# 394   9
#
# [395 rows x 33 columns]

# %%
df["famsize"]=df["famsize"].astype(str)
df["famsize"]=coder.fit_transform(df["famsize"])
df
# Out:
#      school  sex  age  address  famsize Pstatus  Medu  Fedu      Mjob  \
# 0         0    0   18        1        0       A     4     4   at_home
# 1         0    0   17        1        0       T     1     1   at_home
# 2         0    0   15        1        1       T     1     1   at_home
# 3         0    0   15        1        0       T     4     2    health
# 4         0    0   16        1        0       T     3     3     other
# ..      ...  ...  ...      ...      ...     ...   ...   ...       ...
# 390       1    1   20        1        1       A     2     2  services
# 391       1    1   17        1        1       T     3     1  services
# 392       1    1   21        0        0       T     1     1     other
# 393       1    1   18        0        1       T     3     2  services
# 394       1    1   19        1        1       T     1     1     other
#
#          Fjob  ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  \
# 0     teacher  ...      4        3      4     1     1      3        6   5   6
# 1       other  ...      5        3      3     1     1      3        4   5   5
# 2       other  ...      4        3      2     2     3      3       10   7   8
# 3    services  ...      3        2      2     1     1      5        2  15  14
# 4       other  ...      4        3      2     1     2      5        4   6  10
# ..        ...  ...    ...      ...    ...   ...   ...    ...      ...  ..  ..
# 390  services  ...      5        5      4     4     5      4       11   9   9
# 391  services  ...      2        4      5     3     4      2        3  14  16
# 392     other  ...      5        5      3     3     3      3        3  10   8
# 393     other  ...      4        4      1     3     4      5        0  11  12
# 394   at_home  ...      3        2      3     3     3      5        5   8   9
#
#      G3
# 0     6
# 1     6
# 2    10
# 3    15
# 4    10
# ..   ..
# 390   9
# 391  16
# 392   7
# 393  10
# 394   9
#
# [395 rows x 33 columns]

# %%
df["reason"]=df["reason"].astype(str)
df["reason"]=coder.fit_transform(df["reason"])
df
# Out:
#      school  sex  age  address  famsize Pstatus  Medu  Fedu      Mjob  \
# 0         0    0   18        1        0       A     4     4   at_home
# 1         0    0   17        1        0       T     1     1   at_home
# 2         0    0   15        1        1       T     1     1   at_home
# 3         0    0   15        1        0       T     4     2    health
# 4         0    0   16        1        0       T     3     3     other
# ..      ...  ...  ...      ...      ...     ...   ...   ...       ...
# 390       1    1   20        1        1       A     2     2  services
# 391       1    1   17        1        1       T     3     1  services
# 392       1    1   21        0        0       T     1     1     other
# 393       1    1   18        0        1       T     3     2  services
# 394       1    1   19        1        1       T     1     1     other
#
#          Fjob  ...  famrel freetime  goout  Dalc  Walc health absences  G1  \
# 0     teacher  ...       4        3      4     1     1      3        6   5
# 1       other  ...       5        3      3     1     1      3        4   5
# 2       other  ...       4        3      2     2     3      3       10   7
# 3    services  ...       3        2      2     1     1      5        2  15
# 4       other  ...       4        3      2     1     2      5        4   6
# ..        ...  ...     ...      ...    ...   ...   ...    ...      ...  ..
# 390  services  ...       5        5      4     4     5      4       11   9
# 391  services  ...       2        4      5     3     4      2        3  14
# 392     other  ...       5        5      3     3     3      3        3  10
# 393     other  ...       4        4      1     3     4      5        0  11
# 394   at_home  ...       3        2      3     3     3      5        5   8
#
#      G2  G3
# 0     6   6
# 1     5   6
# 2     8  10
# 3    14  15
# 4    10  10
# ..   ..  ..
# 390   9   9
# 391  16  16
# 392   8   7
# 393  12  10
# 394   9   9
#
# [395 rows x 33 columns]

# %%
df["guardian"]=df["guardian"].astype(str)
df["guardian"]=coder.fit_transform(df["guardian"])
df
# Out:
#      school  sex  age  address  famsize Pstatus  Medu  Fedu      Mjob  \
# 0         0    0   18        1        0       A     4     4   at_home
# 1         0    0   17        1        0       T     1     1   at_home
# 2         0    0   15        1        1       T     1     1   at_home
# 3         0    0   15        1        0       T     4     2    health
# 4         0    0   16        1        0       T     3     3     other
# ..      ...  ...  ...      ...      ...     ...   ...   ...       ...
# 390       1    1   20        1        1       A     2     2  services
# 391       1    1   17        1        1       T     3     1  services
# 392       1    1   21        0        0       T     1     1     other
# 393       1    1   18        0        1       T     3     2  services
# 394       1    1   19        1        1       T     1     1     other
#
#          Fjob  ...  famrel  freetime  goout  Dalc  Walc health absences  G1  \
# 0     teacher  ...       4         3      4     1     1      3        6   5
# 1       other  ...       5         3      3     1     1      3        4   5
# 2       other  ...       4         3      2     2     3      3       10   7
# 3    services  ...       3         2      2     1     1      5        2  15
# 4       other  ...       4         3      2     1     2      5        4   6
# ..        ...  ...     ...       ...    ...   ...   ...    ...      ...  ..
# 390  services  ...       5         5      4     4     5      4       11   9
# 391  services  ...       2         4      5     3     4      2        3  14
# 392     other  ...       5         5      3     3     3      3        3  10
# 393     other  ...       4         4      1     3     4      5        0  11
# 394   at_home  ...       3         2      3     3     3      5        5   8
#
#      G2  G3
# 0     6   6
# 1     5   6
# 2     8  10
# 3    14  15
# 4    10  10
# ..   ..  ..
# 390   9   9
# 391  16  16
# 392   8   7
# 393  12  10
# 394   9   9
#
# [395 rows x 33 columns]

# %%
df["Pstatus"]=df["Pstatus"].astype(str)
df["Pstatus"]=coder.fit_transform(df["Pstatus"])
df
# Out:
#      school  sex  age  address  famsize  Pstatus  Medu  Fedu      Mjob  \
# 0         0    0   18        1        0        0     4     4   at_home
# 1         0    0   17        1        0        1     1     1   at_home
# 2         0    0   15        1        1        1     1     1   at_home
# 3         0    0   15        1        0        1     4     2    health
# 4         0    0   16        1        0        1     3     3     other
# ..      ...  ...  ...      ...      ...      ...   ...   ...       ...
# 390       1    1   20        1        1        0     2     2  services
# 391       1    1   17        1        1        1     3     1  services
# 392       1    1   21        0        0        1     1     1     other
# 393       1    1   18        0        1        1     3     2  services
# 394       1    1   19        1        1        1     1     1     other
#
#          Fjob  ...  famrel  freetime  goout  Dalc  Walc health absences  G1  \
# 0     teacher  ...       4         3      4     1     1      3        6   5
# 1       other  ...       5         3      3     1     1      3        4   5
# 2       other  ...       4         3      2     2     3      3       10   7
# 3    services  ...       3         2      2     1     1      5        2  15
# 4       other  ...       4         3      2     1     2      5        4   6
# ..        ...  ...     ...       ...    ...   ...   ...    ...      ...  ..
# 390  services  ...       5         5      4     4     5      4       11   9
# 391  services  ...       2         4      5     3     4      2        3  14
# 392     other  ...       5         5      3     3     3      3        3  10
# 393     other  ...       4         4      1     3     4      5        0  11
# 394   at_home  ...       3         2      3     3     3      5        5   8
#
#      G2  G3
# 0     6   6
# 1     5   6
# 2     8  10
# 3    14  15
# 4    10  10
# ..   ..  ..
# 390   9   9
# 391  16  16
# 392   8   7
# 393  12  10
# 394   9   9
#
# [395 rows x 33 columns]

# %%
df["Medu"]=df["Medu"].astype(str)
df["Medu"]=coder.fit_transform(df["Medu"])
df
# Out:
#      school  sex  age  address  famsize  Pstatus  Medu  Fedu      Mjob  \
# 0         0    0   18        1        0        0     4     4   at_home
# 1         0    0   17        1        0        1     1     1   at_home
# 2         0    0   15        1        1        1     1     1   at_home
# 3         0    0   15        1        0        1     4     2    health
# 4         0    0   16        1        0        1     3     3     other
# ..      ...  ...  ...      ...      ...      ...   ...   ...       ...
# 390       1    1   20        1        1        0     2     2  services
# 391       1    1   17        1        1        1     3     1  services
# 392       1    1   21        0        0        1     1     1     other
# 393       1    1   18        0        1        1     3     2  services
# 394       1    1   19        1        1        1     1     1     other
#
#          Fjob  ...  famrel  freetime  goout  Dalc  Walc health absences  G1  \
# 0     teacher  ...       4         3      4     1     1      3        6   5
# 1       other  ...       5         3      3     1     1      3        4   5
# 2       other  ...       4         3      2     2     3      3       10   7
# 3    services  ...       3         2      2     1     1      5        2  15
# 4       other  ...       4         3      2     1     2      5        4   6
# ..        ...  ...     ...       ...    ...   ...   ...    ...      ...  ..
# 390  services  ...       5         5      4     4     5      4       11   9
# 391  services  ...       2         4      5     3     4      2        3  14
# 392     other  ...       5         5      3     3     3      3        3  10
# 393     other  ...       4         4      1     3     4      5        0  11
# 394   at_home  ...       3         2      3     3     3      5        5   8
#
#      G2  G3
# 0     6   6
# 1     5   6
# 2     8  10
# 3    14  15
# 4    10  10
# ..   ..  ..
# 390   9   9
# 391  16  16
# 392   8   7
# 393  12  10
# 394   9   9
#
# [395 rows x 33 columns]

# %%
df["Mjob"]=df["Mjob"].astype(str)
df["Mjob"]=coder.fit_transform(df["Mjob"])
df
# Out:
#      school  sex  age  address  famsize  Pstatus  Medu  Fedu  Mjob      Fjob  \
# 0         0    0   18        1        0        0     4     4     0   teacher
# 1         0    0   17        1        0        1     1     1     0     other
# 2         0    0   15        1        1        1     1     1     0     other
# 3         0    0   15        1        0        1     4     2     1  services
# 4         0    0   16        1        0        1     3     3     2     other
# ..      ...  ...  ...      ...      ...      ...   ...   ...   ...       ...
# 390       1    1   20        1        1        0     2     2     3  services
# 391       1    1   17        1        1        1     3     1     3  services
# 392       1    1   21        0        0        1     1     1     2     other
# 393       1    1   18        0        1        1     3     2     3     other
# 394       1    1   19        1        1        1     1     1     2   at_home
#
#      ...  famrel  freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0    ...       4         3      4     1     1      3        6   5   6   6
# 1    ...       5         3      3     1     1      3        4   5   5   6
# 2    ...       4         3      2     2     3      3       10   7   8  10
# 3    ...       3         2      2     1     1      5        2  15  14  15
# 4    ...       4         3      2     1     2      5        4   6  10  10
# ..   ...     ...       ...    ...   ...   ...    ...      ...  ..  ..  ..
# 390  ...       5         5      4     4     5      4       11   9   9   9
# 391  ...       2         4      5     3     4      2        3  14  16  16
# 392  ...       5         5      3     3     3      3        3  10   8   7
# 393  ...       4         4      1     3     4      5        0  11  12  10
# 394  ...       3         2      3     3     3      5        5   8   9   9
#
# [395 rows x 33 columns]

# %%
df["Fjob"]=df["Fjob"].astype(str)
df["Fjob"]=coder.fit_transform(df["Fjob"])
df
# Out:
#      school  sex  age  address  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  ...  \
# 0         0    0   18        1        0        0     4     4     0     4  ...
# 1         0    0   17        1        0        1     1     1     0     2  ...
# 2         0    0   15        1        1        1     1     1     0     2  ...
# 3         0    0   15        1        0        1     4     2     1     3  ...
# 4         0    0   16        1        0        1     3     3     2     2  ...
# ..      ...  ...  ...      ...      ...      ...   ...   ...   ...   ...  ...
# 390       1    1   20        1        1        0     2     2     3     3  ...
# 391       1    1   17        1        1        1     3     1     3     3  ...
# 392       1    1   21        0        0        1     1     1     2     2  ...
# 393       1    1   18        0        1        1     3     2     3     2  ...
# 394       1    1   19        1        1        1     1     1     2     0  ...
#
#      famrel  freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0         4         3      4     1     1      3        6   5   6   6
# 1         5         3      3     1     1      3        4   5   5   6
# 2         4         3      2     2     3      3       10   7   8  10
# 3         3         2      2     1     1      5        2  15  14  15
# 4         4         3      2     1     2      5        4   6  10  10
# ..      ...       ...    ...   ...   ...    ...      ...  ..  ..  ..
# 390       5         5      4     4     5      4       11   9   9   9
# 391       2         4      5     3     4      2        3  14  16  16
# 392       5         5      3     3     3      3        3  10   8   7
# 393       4         4      1     3     4      5        0  11  12  10
# 394       3         2      3     3     3      5        5   8   9   9
#
# [395 rows x 33 columns]

# %%
df["famsup"]=df["famsup"].astype(str)
df["famsup"]=coder.fit_transform(df["famsup"])
df
# Out:
#      school  sex  age  address  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  ...  \
# 0         0    0   18        1        0        0     4     4     0     4  ...
# 1         0    0   17        1        0        1     1     1     0     2  ...
# 2         0    0   15        1        1        1     1     1     0     2  ...
# 3         0    0   15        1        0        1     4     2     1     3  ...
# 4         0    0   16        1        0        1     3     3     2     2  ...
# ..      ...  ...  ...      ...      ...      ...   ...   ...   ...   ...  ...
# 390       1    1   20        1        1        0     2     2     3     3  ...
# 391       1    1   17        1        1        1     3     1     3     3  ...
# 392       1    1   21        0        0        1     1     1     2     2  ...
# 393       1    1   18        0        1        1     3     2     3     2  ...
# 394       1    1   19        1        1        1     1     1     2     0  ...
#
#      famrel  freetime  goout  Dalc  Walc health  absences  G1  G2  G3
# 0         4         3      4     1     1      3         6   5   6   6
# 1         5         3      3     1     1      3         4   5   5   6
# 2         4         3      2     2     3      3        10   7   8  10
# 3         3         2      2     1     1      5         2  15  14  15
# 4         4         3      2     1     2      5         4   6  10  10
# ..      ...       ...    ...   ...   ...    ...       ...  ..  ..  ..
# 390       5         5      4     4     5      4        11   9   9   9
# 391       2         4      5     3     4      2         3  14  16  16
# 392       5         5      3     3     3      3         3  10   8   7
# 393       4         4      1     3     4      5         0  11  12  10
# 394       3         2      3     3     3      5         5   8   9   9
#
# [395 rows x 33 columns]

# %%
df["activities"]=df["activities"].astype(str)
df["activities"]=coder.fit_transform(df["activities"])
df
# Out:
#      school  sex  age  address  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  ...  \
# 0         0    0   18        1        0        0     4     4     0     4  ...
# 1         0    0   17        1        0        1     1     1     0     2  ...
# 2         0    0   15        1        1        1     1     1     0     2  ...
# 3         0    0   15        1        0        1     4     2     1     3  ...
# 4         0    0   16        1        0        1     3     3     2     2  ...
# ..      ...  ...  ...      ...      ...      ...   ...   ...   ...   ...  ...
# 390       1    1   20        1        1        0     2     2     3     3  ...
# 391       1    1   17        1        1        1     3     1     3     3  ...
# 392       1    1   21        0        0        1     1     1     2     2  ...
# 393       1    1   18        0        1        1     3     2     3     2  ...
# 394       1    1   19        1        1        1     1     1     2     0  ...
#
#      famrel  freetime  goout  Dalc  Walc health  absences  G1  G2  G3
# 0         4         3      4     1     1      3         6   5   6   6
# 1         5         3      3     1     1      3         4   5   5   6
# 2         4         3      2     2     3      3        10   7   8  10
# 3         3         2      2     1     1      5         2  15  14  15
# 4         4         3      2     1     2      5         4   6  10  10
# ..      ...       ...    ...   ...   ...    ...       ...  ..  ..  ..
# 390       5         5      4     4     5      4        11   9   9   9
# 391       2         4      5     3     4      2         3  14  16  16
# 392       5         5      3     3     3      3         3  10   8   7
# 393       4         4      1     3     4      5         0  11  12  10
# 394       3         2      3     3     3      5         5   8   9   9
#
# [395 rows x 33 columns]

# %%
df["paid"]=df["paid"].astype(str)
df["paid"]=coder.fit_transform(df["paid"])
df
# Out:
#      school  sex  age  address  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  ...  \
# 0         0    0   18        1        0        0     4     4     0     4  ...
# 1         0    0   17        1        0        1     1     1     0     2  ...
# 2         0    0   15        1        1        1     1     1     0     2  ...
# 3         0    0   15        1        0        1     4     2     1     3  ...
# 4         0    0   16        1        0        1     3     3     2     2  ...
# ..      ...  ...  ...      ...      ...      ...   ...   ...   ...   ...  ...
# 390       1    1   20        1        1        0     2     2     3     3  ...
# 391       1    1   17        1        1        1     3     1     3     3  ...
# 392       1    1   21        0        0        1     1     1     2     2  ...
# 393       1    1   18        0        1        1     3     2     3     2  ...
# 394       1    1   19        1        1        1     1     1     2     0  ...
#
#      famrel  freetime  goout  Dalc  Walc health  absences  G1  G2  G3
# 0         4         3      4     1     1      3         6   5   6   6
# 1         5         3      3     1     1      3         4   5   5   6
# 2         4         3      2     2     3      3        10   7   8  10
# 3         3         2      2     1     1      5         2  15  14  15
# 4         4         3      2     1     2      5         4   6  10  10
# ..      ...       ...    ...   ...   ...    ...       ...  ..  ..  ..
# 390       5         5      4     4     5      4        11   9   9   9
# 391       2         4      5     3     4      2         3  14  16  16
# 392       5         5      3     3     3      3         3  10   8   7
# 393       4         4      1     3     4      5         0  11  12  10
# 394       3         2      3     3     3      5         5   8   9   9
#
# [395 rows x 33 columns]

# %%
df["nursery"]=df["nursery"].astype(str)
df["nursery"]=coder.fit_transform(df["nursery"])
df
# Out:
#      school  sex  age  address  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  ...  \
# 0         0    0   18        1        0        0     4     4     0     4  ...
# 1         0    0   17        1        0        1     1     1     0     2  ...
# 2         0    0   15        1        1        1     1     1     0     2  ...
# 3         0    0   15        1        0        1     4     2     1     3  ...
# 4         0    0   16        1        0        1     3     3     2     2  ...
# ..      ...  ...  ...      ...      ...      ...   ...   ...   ...   ...  ...
# 390       1    1   20        1        1        0     2     2     3     3  ...
# 391       1    1   17        1        1        1     3     1     3     3  ...
# 392       1    1   21        0        0        1     1     1     2     2  ...
# 393       1    1   18        0        1        1     3     2     3     2  ...
# 394       1    1   19        1        1        1     1     1     2     0  ...
#
#      famrel  freetime  goout  Dalc  Walc health  absences  G1  G2  G3
# 0         4         3      4     1     1      3         6   5   6   6
# 1         5         3      3     1     1      3         4   5   5   6
# 2         4         3      2     2     3      3        10   7   8  10
# 3         3         2      2     1     1      5         2  15  14  15
# 4         4         3      2     1     2      5         4   6  10  10
# ..      ...       ...    ...   ...   ...    ...       ...  ..  ..  ..
# 390       5         5      4     4     5      4        11   9   9   9
# 391       2         4      5     3     4      2         3  14  16  16
# 392       5         5      3     3     3      3         3  10   8   7
# 393       4         4      1     3     4      5         0  11  12  10
# 394       3         2      3     3     3      5         5   8   9   9
#
# [395 rows x 33 columns]

# %%
df["higher"]=df["higher"].astype(str)
df["higher"]=coder.fit_transform(df["higher"])
df
# Out:
#      school  sex  age  address  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  ...  \
# 0         0    0   18        1        0        0     4     4     0     4  ...
# 1         0    0   17        1        0        1     1     1     0     2  ...
# 2         0    0   15        1        1        1     1     1     0     2  ...
# 3         0    0   15        1        0        1     4     2     1     3  ...
# 4         0    0   16        1        0        1     3     3     2     2  ...
# ..      ...  ...  ...      ...      ...      ...   ...   ...   ...   ...  ...
# 390       1    1   20        1        1        0     2     2     3     3  ...
# 391       1    1   17        1        1        1     3     1     3     3  ...
# 392       1    1   21        0        0        1     1     1     2     2  ...
# 393       1    1   18        0        1        1     3     2     3     2  ...
# 394       1    1   19        1        1        1     1     1     2     0  ...
#
#      famrel  freetime  goout  Dalc  Walc health  absences  G1  G2  G3
# 0         4         3      4     1     1      3         6   5   6   6
# 1         5         3      3     1     1      3         4   5   5   6
# 2         4         3      2     2     3      3        10   7   8  10
# 3         3         2      2     1     1      5         2  15  14  15
# 4         4         3      2     1     2      5         4   6  10  10
# ..      ...       ...    ...   ...   ...    ...       ...  ..  ..  ..
# 390       5         5      4     4     5      4        11   9   9   9
# 391       2         4      5     3     4      2         3  14  16  16
# 392       5         5      3     3     3      3         3  10   8   7
# 393       4         4      1     3     4      5         0  11  12  10
# 394       3         2      3     3     3      5         5   8   9   9
#
# [395 rows x 33 columns]

# %%
df["schoolsup"]=df["schoolsup"].astype(str)
df["schoolsup"]=coder.fit_transform(df["schoolsup"])
df
# Out:
#      school  sex  age  address  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  ...  \
# 0         0    0   18        1        0        0     4     4     0     4  ...
# 1         0    0   17        1        0        1     1     1     0     2  ...
# 2         0    0   15        1        1        1     1     1     0     2  ...
# 3         0    0   15        1        0        1     4     2     1     3  ...
# 4         0    0   16        1        0        1     3     3     2     2  ...
# ..      ...  ...  ...      ...      ...      ...   ...   ...   ...   ...  ...
# 390       1    1   20        1        1        0     2     2     3     3  ...
# 391       1    1   17        1        1        1     3     1     3     3  ...
# 392       1    1   21        0        0        1     1     1     2     2  ...
# 393       1    1   18        0        1        1     3     2     3     2  ...
# 394       1    1   19        1        1        1     1     1     2     0  ...
#
#      famrel  freetime  goout  Dalc  Walc  health  absences  G1  G2  G3
# 0         4         3      4     1     1       3         6   5   6   6
# 1         5         3      3     1     1       3         4   5   5   6
# 2         4         3      2     2     3       3        10   7   8  10
# 3         3         2      2     1     1       5         2  15  14  15
# 4         4         3      2     1     2       5         4   6  10  10
# ..      ...       ...    ...   ...   ...     ...       ...  ..  ..  ..
# 390       5         5      4     4     5       4        11   9   9   9
# 391       2         4      5     3     4       2         3  14  16  16
# 392       5         5      3     3     3       3         3  10   8   7
# 393       4         4      1     3     4       5         0  11  12  10
# 394       3         2      3     3     3       5         5   8   9   9
#
# [395 rows x 33 columns]

# %%
df["internet"]=df["internet"].astype(str)
df["internet"]=coder.fit_transform(df["internet"])
df
# Out:
#      school  sex  age  address  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  ...  \
# 0         0    0   18        1        0        0     4     4     0     4  ...
# 1         0    0   17        1        0        1     1     1     0     2  ...
# 2         0    0   15        1        1        1     1     1     0     2  ...
# 3         0    0   15        1        0        1     4     2     1     3  ...
# 4         0    0   16        1        0        1     3     3     2     2  ...
# ..      ...  ...  ...      ...      ...      ...   ...   ...   ...   ...  ...
# 390       1    1   20        1        1        0     2     2     3     3  ...
# 391       1    1   17        1        1        1     3     1     3     3  ...
# 392       1    1   21        0        0        1     1     1     2     2  ...
# 393       1    1   18        0        1        1     3     2     3     2  ...
# 394       1    1   19        1        1        1     1     1     2     0  ...
#
#      famrel  freetime  goout  Dalc  Walc  health  absences  G1  G2  G3
# 0         4         3      4     1     1       3         6   5   6   6
# 1         5         3      3     1     1       3         4   5   5   6
# 2         4         3      2     2     3       3        10   7   8  10
# 3         3         2      2     1     1       5         2  15  14  15
# 4         4         3      2     1     2       5         4   6  10  10
# ..      ...       ...    ...   ...   ...     ...       ...  ..  ..  ..
# 390       5         5      4     4     5       4        11   9   9   9
# 391       2         4      5     3     4       2         3  14  16  16
# 392       5         5      3     3     3       3         3  10   8   7
# 393       4         4      1     3     4       5         0  11  12  10
# 394       3         2      3     3     3       5         5   8   9   9
#
# [395 rows x 33 columns]

# %%
import matplotlib.pyplot
plt = matplotlib.pyplot

# %%
plt.plot(df["absences"],df["G3"])
plt.xlabel("absences")
plt.ylabel("G3")
plt.show()

# %%
plt.scatter(df["absences"],df["G3"])
plt.xlabel("absences")
plt.ylabel("G3")
plt.show()

# %%
plt.bar(df["absences"],df["G3"])
plt.xlabel("absences")
plt.ylabel("G3")
plt.show()

# %%
plt.hist(df["absences"])
plt.xlabel("absences")
plt.ylabel("Frequency")
plt.title("Distribution of Absences")
plt.show()

# %%
import seaborn as sus

# %%
sus.scatterplot(x=df["absences"],y=df["G3"])
plt.xlabel("absences")
plt.ylabel("G3")
plt.show()

# %%
sus.boxplot(x=df["absences"],y=df["G3"])
plt.xlabel("absences")
plt.ylabel("G3")
plt.show()

# %%
sus.barplot(x=df["absences"],y=df["G3"])
plt.xlabel("absences")
plt.ylabel("G3")
plt.show()

# %%
sus.violinplot(x=df["absences"],y=df["G3"])
plt.xlabel("absences")
plt.ylabel("G3")
plt.show()

# %%
sus.lineplot(x=df["absences"],y=df["G3"])
plt.xlabel("absences")
plt.ylabel("G3")
plt.show()

# %%
x=(df.drop(columns=["G3"]))
y=df["G3"]

# %%
x
# Out:
#      school  sex  age  address  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  ...  \
# 0         0    0   18        1        0        0     4     4     0     4  ...
# 1         0    0   17        1        0        1     1     1     0     2  ...
# 2         0    0   15        1        1        1     1     1     0     2  ...
# 3         0    0   15        1        0        1     4     2     1     3  ...
# 4         0    0   16        1        0        1     3     3     2     2  ...
# ..      ...  ...  ...      ...      ...      ...   ...   ...   ...   ...  ...
# 390       1    1   20        1        1        0     2     2     3     3  ...
# 391       1    1   17        1        1        1     3     1     3     3  ...
# 392       1    1   21        0        0        1     1     1     2     2  ...
# 393       1    1   18        0        1        1     3     2     3     2  ...
# 394       1    1   19        1        1        1     1     1     2     0  ...
#
#      romantic  famrel  freetime  goout  Dalc  Walc  health  absences  G1  G2
# 0           0       4         3      4     1     1       3         6   5   6
# 1           0       5         3      3     1     1       3         4   5   5
# 2           0       4         3      2     2     3       3        10   7   8
# 3           1       3         2      2     1     1       5         2  15  14
# 4           0       4         3      2     1     2       5         4   6  10
# ..        ...     ...       ...    ...   ...   ...     ...       ...  ..  ..
# 390         0       5         5      4     4     5       4        11   9   9
# 391         0       2         4      5     3     4       2         3  14  16
# 392         0       5         5      3     3     3       3         3  10   8
# 393         0       4         4      1     3     4       5         0  11  12
# 394         0       3         2      3     3     3       5         5   8   9
#
# [395 rows x 32 columns]

# %%
y
# Out:
# 0       6
# 1       6
# 2      10
# 3      15
# 4      10
#        ..
# 390     9
# 391    16
# 392     7
# 393    10
# 394     9
# Name: G3, Length: 395, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_test, x_train, y_test, y_train = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
x_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 316 entries, 181 to 102
# Data columns (total 32 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      316 non-null    int64
#  1   sex         316 non-null    int64
#  2   age         316 non-null    int64
#  3   address     316 non-null    int64
#  4   famsize     316 non-null    int64
#  5   Pstatus     316 non-null    int64
#  6   Medu        316 non-null    int64
#  7   Fedu        316 non-null    int64
#  8   Mjob        316 non-null    int64
#  9   Fjob        316 non-null    int64
#  10  reason      316 non-null    int64
#  11  guardian    316 non-null    int64
#  12  traveltime  316 non-null    int64
#  13  studytime   316 non-null    int64
#  14  failures    316 non-null    int64
#  15  schoolsup   316 non-null    int64
#  16  famsup      316 non-null    int64
#  17  paid        316 non-null    int64
#  18  activities  316 non-null    int64
#  19  nursery     316 non-null    int64
#  20  higher      316 non-null    int64
#  21  internet    316 non-null    int64
#  22  romantic    316 non-null    int64
#  23  famrel      316 non-null    int64
#  24  freetime    316 non-null    int64
#  25  goout       316 non-null    int64
#  26  Dalc        316 non-null    int64
#  27  Walc        316 non-null    int64
#  28  health      316 non-null    int64
#  29  absences    316 non-null    int64
#  30  G1          316 non-null    int64
#  31  G2          316 non-null    int64
# dtypes: int64(32)
# memory usage: 81.5 KB

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 79 entries, 78 to 18
# Data columns (total 32 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      79 non-null     int64
#  1   sex         79 non-null     int64
#  2   age         79 non-null     int64
#  3   address     79 non-null     int64
#  4   famsize     79 non-null     int64
#  5   Pstatus     79 non-null     int64
#  6   Medu        79 non-null     int64
#  7   Fedu        79 non-null     int64
#  8   Mjob        79 non-null     int64
#  9   Fjob        79 non-null     int64
#  10  reason      79 non-null     int64
#  11  guardian    79 non-null     int64
#  12  traveltime  79 non-null     int64
#  13  studytime   79 non-null     int64
#  14  failures    79 non-null     int64
#  15  schoolsup   79 non-null     int64
#  16  famsup      79 non-null     int64
#  17  paid        79 non-null     int64
#  18  activities  79 non-null     int64
#  19  nursery     79 non-null     int64
#  20  higher      79 non-null     int64
#  21  internet    79 non-null     int64
#  22  romantic    79 non-null     int64
#  23  famrel      79 non-null     int64
#  24  freetime    79 non-null     int64
#  25  goout       79 non-null     int64
#  26  Dalc        79 non-null     int64
#  27  Walc        79 non-null     int64
#  28  health      79 non-null     int64
#  29  absences    79 non-null     int64
#  30  G1          79 non-null     int64
#  31  G2          79 non-null     int64
# dtypes: int64(32)
# memory usage: 20.4 KB

# %%
y_train.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 79 entries, 78 to 18
# Series name: G3
# Non-Null Count  Dtype
# --------------  -----
# 79 non-null     int64
# dtypes: int64(1)
# memory usage: 1.2 KB

# %%
y_test.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 316 entries, 181 to 102
# Series name: G3
# Non-Null Count  Dtype
# --------------  -----
# 316 non-null    int64
# dtypes: int64(1)
# memory usage: 4.9 KB

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
pred=model.fit(x_train,y_train)

# %%
pred=model.predict(x_test)

# %%
pred
# Out:
# array([ 1.31811549e+01,  1.35750921e+01,  9.20615321e+00,  6.88107402e+00,
#         8.38150128e+00,  8.63464630e+00,  1.21134295e+01,  5.51637772e+00,
#         1.13011885e+01,  1.61641420e+01,  2.92232189e-01,  1.26513735e+01,
#         8.55647566e+00,  9.65557866e+00,  1.00854921e+01,  7.26619995e+00,
#         6.72265680e+00,  8.10910450e+00,  1.65099491e+01,  1.91089010e+01,
#         1.40328302e+01,  1.47007047e+01,  1.19723977e+01,  1.42368170e+00,
#         1.03971752e+01,  1.13909591e+01,  7.53440899e+00,  8.37405958e+00,
#         5.17293396e+00,  7.33376694e+00,  8.65642926e+00,  7.36780344e+00,
#         4.55015104e+00,  1.12376950e+01,  3.95247523e+00,  1.00130928e+01,
#         1.73492501e+01,  7.84065047e+00,  7.41625266e+00,  1.55756083e+01,
#         9.26545743e+00,  1.21499305e+01,  4.89246552e+00,  1.00230559e+01,
#         1.37825105e+01,  1.55871467e+01,  9.93694665e+00,  1.05649070e+01,
#         9.61762220e+00, -3.70859868e-01,  4.69935225e+00,  9.91813779e+00,
#         1.13662457e+01,  1.51727641e+01,  3.90915831e+00,  1.85690895e+01,
#         1.68719727e+01,  4.87280371e+00,  7.99290471e+00,  1.51715571e+01,
#         1.07451357e+01,  1.23124507e+01,  1.20643493e+01,  1.14337907e+01,
#         1.34910645e+01,  6.64726118e+00,  1.02550692e+01,  1.65480149e+01,
#         1.11873035e+01,  6.79549052e+00,  1.49032334e+01,  6.64929544e+00,
#         7.82404024e+00,  9.90458464e+00,  2.84138417e+00,  9.30669992e+00,
#         1.10331081e+01,  1.41689701e+01,  7.50224871e+00,  1.45257661e+01,
#         1.12295477e+01,  7.47229546e+00,  6.19358711e+00,  5.16725616e+00,
#         9.95032837e+00,  1.55823157e+01,  3.73801580e+00,  1.68803667e+01,
#         1.17216322e+01,  1.24374092e+01,  1.38226764e+01,  1.47922721e+01,
#         6.69045298e+00,  9.00611069e+00,  7.41113939e+00,  1.41074601e+01,
#         1.63222059e+01, -6.80969040e-01,  1.26753099e+01,  2.89646227e+00,
#         7.06196766e+00,  1.01066720e+01,  1.04282389e+01,  1.23473229e+01,
#         1.03812009e+01,  1.20497963e+01,  7.70707299e+00,  9.32370380e+00,
#         5.63720629e+00, -1.47084952e+00,  7.31130845e+00,  7.66844385e+00,
#         1.52104026e+01,  1.03659950e+01,  1.17011482e+01,  1.11932540e+01,
#         4.02548827e+00,  1.07844374e+01,  1.20178796e+01,  7.36744511e+00,
#         1.91183398e+01,  8.20810843e+00,  1.13126892e+01,  1.01305695e+01,
#         1.18435869e+01,  1.38877855e+01,  1.18205462e+01,  7.83218906e+00,
#         1.60722666e+01,  9.12212438e+00,  1.49488257e+01,  1.49083762e+01,
#         7.51301539e+00,  1.15265950e+01,  6.29707603e+00,  1.40485350e+01,
#         1.05102003e+01,  9.84676904e+00, -1.73693650e-02,  9.41863838e+00,
#         1.04610548e+01,  7.75781990e+00,  4.34865185e+00,  1.04864542e+01,
#         7.91431496e+00,  1.38244777e+01,  7.26705571e+00,  8.40742296e+00,
#         1.10189012e+01,  1.53131209e+01,  1.14913224e+01,  1.21103160e+01,
#         1.38370460e+01,  1.28419776e+01,  1.32226389e+01,  1.22160159e+01,
#         7.95700816e+00,  1.21686155e+01,  1.03701897e+01,  1.24178568e+01,
#         1.64684023e+01,  1.71511321e+01,  1.61255509e+01,  7.60678713e+00,
#         8.65619418e+00,  1.22537493e+01, -2.52333174e+00,  1.28320957e+01,
#         1.70757305e+01,  8.71707339e+00,  1.22192973e+01,  1.47772814e+01,
#         1.32328732e+01,  1.32337112e+01, -1.33937520e+00,  1.17083025e+01,
#         1.39681287e+01,  1.21443015e+01,  1.47702625e+01,  8.12147098e+00,
#         8.20601770e+00,  5.32669990e+00,  9.00736176e+00,  1.33483306e+01,
#         9.81904154e+00,  5.00959370e+00,  6.13795591e+00,  1.30134542e+01,
#         1.39004592e+01,  1.17126131e+01,  1.18506969e+01,  7.75158536e+00,
#         1.37253052e+01,  9.46889401e+00,  6.12051008e+00,  1.11718320e+01,
#         7.33517000e+00,  9.27143393e+00,  1.08043247e+01,  5.94666757e+00,
#         6.44395543e+00,  1.54218134e+01,  7.52358451e+00,  5.97584014e+00,
#         1.50140978e+01,  1.60509115e+01,  1.70205526e+01,  7.24949257e+00,
#         2.02340800e+01,  1.46304130e+01,  9.49495904e+00,  1.69517991e+01,
#         1.29975204e+01,  1.77372662e+01,  1.47563799e+01,  1.53295705e+01,
#         1.76426885e+01,  1.38428968e+01,  1.17307473e+00,  1.48002354e+01,
#         1.30196834e+01,  9.66602627e+00, -1.32563466e+00,  2.67232052e+00,
#         1.64980163e+01,  1.23341487e+01,  8.84955220e+00,  1.58593412e+01,
#         1.22019161e+01,  1.07670309e+01,  1.48286371e+01,  1.13708623e+01,
#         9.62183812e+00,  9.76229326e+00,  8.11937928e+00,  1.52879495e+01,
#         1.28624227e+01,  1.06419617e+01,  1.21269056e+01,  1.51113958e+01,
#         9.84430418e+00,  1.01433290e+01,  1.46472133e+01,  1.71731134e+01,
#        -1.53856607e+00,  1.00367056e+01,  7.83667407e+00,  5.18228667e+00,
#         4.05133836e+00,  1.08820965e+01,  1.03323963e+01,  8.81047293e+00,
#         1.04246257e+01,  7.66775501e+00,  2.28279989e+00,  6.25573810e+00,
#         1.08572431e+01,  1.12749387e+01,  1.30419783e+01,  8.16200247e+00,
#         2.01911880e+01,  7.80308622e+00,  1.43196145e+01,  8.73958975e+00,
#         8.00747020e+00,  8.64522015e+00,  1.11260792e+01,  1.19525478e+01,
#         1.36294310e+01,  9.64831052e+00,  7.83132679e+00,  5.90542903e+00,
#        -4.18876533e-01,  1.69182417e+01,  1.55736057e+01,  8.67362218e+00,
#         1.24861499e+01,  1.48053841e+01,  1.19994369e+01,  1.09372735e+01,
#         8.29748597e+00,  8.36659770e+00,  1.49477842e+01,  1.57012504e+01,
#         6.76350011e+00,  1.39069607e+01,  7.81888642e+00,  1.19535807e+01,
#         9.60579343e+00,  1.55531879e+01,  1.11231475e+01,  7.19510214e+00,
#         1.01020543e+01,  6.88792294e+00,  1.59503380e+01,  8.10141703e+00,
#         9.46568590e+00,  1.40123119e+01,  1.18814597e+01, -1.21355593e-01,
#         1.61032271e+01,  1.64150311e+01,  4.27728372e+00,  1.19672957e+01,
#         1.52138273e+01,  5.71219992e+00,  9.45704583e+00,  1.34522934e+01,
#         6.70964485e+00,  1.53473405e+01,  8.18870791e+00,  8.23855632e+00,
#         3.67493104e+00,  8.25961307e+00,  1.70195639e+01,  1.15985880e+01])

# %%
accuracy=model.score(x_test,y_test)

# %%
accuracy
# Out:
# 0.6844752428085862

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
model=DecisionTreeRegressor()

# %%
model.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
pred=model.predict(x_test)

# %%
pred
# Out:
# array([13., 14.,  0.,  9., 10.,  9., 12.,  8., 12., 16.,  0., 15., 10.,
#        14.,  9.,  8.,  0.,  9., 17., 17., 15., 15., 12.,  6.,  9., 12.,
#        10., 10., 10., 10., 10.,  6.,  6., 12.,  6.,  9., 19.,  0.,  8.,
#        15.,  9., 12.,  9., 10., 16., 13., 12., 12.,  8.,  8.,  8., 12.,
#        12., 14.,  0., 19., 17.,  0., 10., 16., 14.,  9., 12., 11., 17.,
#         8., 12., 16., 12., 12., 15.,  0.,  8.,  6.,  6., 12., 12., 13.,
#        10., 15., 10.,  6.,  6.,  6., 11., 17.,  6., 16., 12., 15., 12.,
#        15.,  9., 10.,  9., 14., 16.,  0., 12.,  0.,  6.,  9., 14., 12.,
#         6., 15.,  8., 10., 10.,  8.,  9.,  8., 16., 10., 13., 10.,  6.,
#        12., 13.,  9., 19., 12., 10., 10., 12., 13., 14., 10., 18., 10.,
#        13., 15.,  9., 11.,  9., 12.,  0.,  9.,  0., 12., 10., 10.,  0.,
#         6.,  0., 15.,  6., 11., 12., 16., 12., 15., 14., 15., 14., 10.,
#        10., 11., 12., 10., 15., 16., 18.,  9.,  9., 12.,  0., 13., 18.,
#         9., 10., 15., 14.,  8.,  0., 10., 15., 11., 15.,  8., 10.,  0.,
#        10., 13.,  9.,  8.,  0., 13., 12., 13., 12.,  9., 12., 10.,  8.,
#        11., 10.,  9., 12., 10.,  6., 16.,  8.,  6., 15., 14., 15., 10.,
#        18., 16.,  9., 17., 12., 17., 12., 13., 18., 15.,  0., 16., 14.,
#        10.,  0.,  8., 18., 10.,  9., 16., 12.,  8., 14., 12.,  5., 10.,
#         9., 13., 10., 13., 12., 15., 12.,  9., 12., 18.,  0.,  9.,  8.,
#         0.,  5., 10.,  9.,  0., 11.,  9.,  6.,  9., 11.,  9., 13., 10.,
#        19., 10., 11., 10., 10., 10., 12.,  9., 13.,  9.,  9., 10.,  0.,
#        19., 16., 10., 12., 13., 14., 11., 10., 10., 16., 13.,  9., 15.,
#        10., 10.,  8., 15.,  9.,  0., 10.,  0., 18.,  8., 10., 12.,  8.,
#         0., 12., 17., 10., 12., 14.,  0., 10., 15., 10., 14.,  9.,  0.,
#         0.,  9., 15., 12.])

# %%
accuracy=model.score(x_test,y_test)

# %%
accuracy
# Out:
# 0.6415779905570015

# %%
from sklearn.ensemble import RandomForestRegressor
model=RandomForestRegressor()

# %%
model.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
pred=model.predict(x_test)

# %%
pred
# Out:
# array([13.66, 14.31,  5.03,  8.75,  5.19,  8.6 , 13.84,  4.71, 11.54,
#        15.35,  3.11, 13.46,  9.01, 10.99,  8.92,  3.93,  7.07,  9.03,
#        17.29, 17.6 , 14.41, 13.81, 11.42,  5.16,  9.97, 11.04,  7.41,
#         9.98,  6.8 ,  8.73,  6.16,  6.1 ,  5.53, 11.11,  5.76,  9.08,
#        17.93,  4.04,  7.33, 14.83, 10.21, 11.04,  8.15,  9.16, 15.43,
#        13.57, 11.42, 11.93,  5.83,  3.94,  8.51, 12.3 , 11.54, 13.75,
#         1.66, 17.98, 16.67,  3.63, 10.96, 16.47, 11.95,  9.8 , 12.74,
#        11.29, 16.31,  8.16, 11.63, 15.06, 11.87,  9.08, 13.85,  3.9 ,
#         5.99,  8.02,  5.79, 10.07, 10.9 , 13.63,  8.91, 13.44, 10.24,
#         8.25,  5.74,  6.04, 10.81, 16.43,  5.95, 16.21, 11.26, 14.84,
#        14.  , 15.28,  9.  ,  8.68,  8.11, 13.35, 16.32,  3.68, 13.43,
#         5.86,  8.72,  8.84, 12.1 , 11.95,  8.54, 13.62,  4.28, 10.03,
#         7.41,  4.3 ,  9.65,  5.44, 15.48, 10.11, 13.64,  8.68,  5.48,
#        11.2 , 13.38,  8.12, 18.29, 11.88, 11.88,  9.35, 11.86, 13.59,
#        13.29,  9.99, 17.03,  8.72, 14.51, 15.07,  9.28,  9.75,  9.04,
#        12.08,  4.42,  7.75,  4.57, 10.92,  6.95,  9.25,  2.88,  8.05,
#         9.33, 15.13,  8.12, 10.94, 11.86, 15.5 , 12.16, 13.87, 11.66,
#        15.24, 11.57, 11.31,  7.72, 11.61, 10.94, 11.44, 15.44, 15.04,
#        17.35,  5.72,  5.62, 10.93,  2.75, 13.42, 17.71,  9.49, 11.09,
#        15.32, 11.71,  8.31,  2.26, 11.8 , 14.95, 11.47, 14.33,  5.09,
#        10.99,  2.71, 10.82, 13.35,  8.68,  4.05,  8.01, 13.25, 11.63,
#        13.54, 12.13,  9.09, 11.41,  7.29,  7.08, 11.32,  9.87,  9.82,
#        12.09,  9.05,  7.12, 15.08,  6.4 ,  6.5 , 14.98, 13.97, 15.09,
#         8.31, 17.76, 16.6 , 10.33, 16.16, 13.18, 16.19, 14.  , 13.55,
#        17.38, 14.13,  3.97, 15.04, 11.64,  9.88,  4.45,  3.88, 17.43,
#         9.85, 10.03, 16.34, 12.07,  9.65, 11.75, 11.11,  5.08, 10.58,
#         9.5 , 13.3 , 11.68, 13.56, 11.9 , 14.29,  9.81,  8.92, 12.77,
#        16.97,  3.55, 10.17,  8.09,  4.06,  5.25, 11.62,  9.85,  3.98,
#        11.24,  9.11,  5.42,  6.61, 11.85,  8.56, 14.2 ,  8.94, 17.18,
#        10.33, 11.11,  9.33, 10.89, 10.32, 11.2 ,  9.9 , 14.12, 10.17,
#         9.16,  4.33,  4.09, 17.5 , 15.4 , 10.82, 12.14, 13.  , 13.07,
#        11.28,  8.65,  9.1 , 15.5 , 14.24,  9.85, 15.29,  9.95,  8.77,
#         8.11, 15.04, 10.03,  3.17,  8.29,  4.51, 17.83,  6.08, 10.86,
#        12.47,  5.51,  3.92, 13.05, 16.74,  4.2 , 11.3 , 14.13,  7.08,
#         9.99, 14.19,  8.96, 14.42,  7.38,  8.08,  5.56,  8.75, 15.09,
#        13.47])

# %%
accuracy=model.score(x_test,y_test)

# %%
accuracy
# Out:
# 0.8272402901269031

# %%
from sklearn.svm import SVC

# %%
model=SVC()

# %%
model.fit(x_train,y_train)
# Out:
# SVC()

# %%
pred=model.predict(x_test)

# %%
pred
# Out:
# array([15, 15, 10, 10, 10, 10, 15, 10, 10, 15, 10, 10, 10, 15, 10, 10, 10,
#        10, 15, 15, 15, 15, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10,
#        10, 10, 15, 10, 10, 15, 10, 10, 10, 10, 15, 15, 10, 10, 10, 10, 10,
#        15, 15, 15, 10, 15, 15, 10, 10, 15, 15, 10, 10, 10, 15, 10, 10, 15,
#        15, 10, 15, 10, 10, 10,  6, 10, 10, 15, 10, 15, 10, 10,  6,  6, 10,
#        15, 10, 15, 10, 15, 15, 15, 10, 10, 10, 15, 15, 10, 15, 10, 10, 10,
#        15, 15,  8, 15, 10, 10, 10, 10, 10, 10, 15, 10, 15,  8, 10, 10, 15,
#        10, 15, 15, 10, 10, 10, 15, 10, 10, 15, 10, 15, 15, 10, 10, 10, 15,
#        10, 10, 10, 10, 10, 10, 10, 10, 10, 15, 10, 10, 15, 15, 15, 15, 10,
#        15, 10, 10, 10,  8, 10, 10, 15, 15, 15, 10, 10, 10, 10, 10, 15, 10,
#        10, 15, 10, 10, 10, 10, 15, 10, 15, 10, 10, 10, 10, 15, 10, 10, 10,
#        15, 10, 15, 15, 10, 10, 10, 10, 10, 10, 10, 15, 10, 10, 15, 10, 10,
#        15, 15, 15, 10, 15, 15, 10, 15, 15, 15, 15, 15, 15, 15, 10, 15, 15,
#        10, 10, 10, 15, 10, 10, 15, 15,  6, 15, 10,  6, 10, 10, 15, 10, 15,
#        15, 15, 10, 10, 15, 15, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10,
#        10, 10,  6, 15, 10, 15, 10, 10, 10, 10, 10,  8, 10, 15, 10, 10, 10,
#        10, 15, 15, 10, 15, 10, 15, 10, 10, 10, 15, 15, 10, 15, 10, 10, 10,
#        15, 10, 10,  8, 10, 15, 10, 10, 15, 10, 10, 10, 15, 10, 10, 15, 10,
#        10, 15, 10, 15, 10, 10, 10, 10, 15, 10])

# %%
accuracy=model.score(x_test,y_test)

# %%
accuracy
# Out:
# 0.22468354430379747

# %%
from sklearn.cluster import KMeans

# %%
model=KMeans

# %%
model.fit(x_train,y_train)
# Out:
# KMeans()

# %%
model.predict(x_test)
# Out:
# array([1, 2, 4, 1, 4, 7, 3, 4, 1, 3, 4, 0, 1, 1, 1, 4, 6, 6, 2, 2, 3, 2,
#        0, 6, 6, 1, 6, 1, 7, 0, 1, 4, 7, 6, 7, 0, 3, 4, 4, 2, 6, 0, 1, 4,
#        3, 1, 1, 1, 4, 4, 4, 1, 1, 3, 4, 0, 2, 4, 1, 2, 1, 6, 0, 1, 2, 4,
#        1, 2, 1, 1, 2, 4, 4, 7, 7, 1, 0, 2, 4, 3, 1, 6, 7, 7, 1, 2, 4, 3,
#        0, 2, 1, 2, 4, 0, 4, 1, 3, 4, 2, 4, 6, 6, 1, 3, 5, 2, 4, 0, 4, 4,
#        1, 4, 2, 1, 2, 5, 4, 1, 0, 0, 3, 1, 1, 1, 0, 2, 6, 1, 3, 7, 2, 2,
#        1, 0, 4, 1, 4, 7, 4, 1, 4, 6, 4, 6, 6, 2, 0, 1, 1, 2, 2, 2, 0, 3,
#        0, 1, 4, 5, 1, 0, 2, 2, 2, 1, 4, 0, 4, 0, 3, 0, 1, 2, 0, 6, 4, 1,
#        2, 1, 2, 4, 1, 4, 1, 0, 6, 4, 4, 1, 0, 3, 3, 6, 3, 6, 6, 1, 6, 4,
#        3, 4, 7, 3, 4, 7, 2, 3, 2, 6, 2, 2, 6, 2, 1, 2, 2, 0, 0, 3, 4, 0,
#        1, 6, 4, 4, 2, 1, 0, 2, 3, 7, 1, 1, 7, 6, 1, 1, 0, 1, 2, 2, 6, 1,
#        1, 2, 4, 6, 6, 4, 7, 0, 0, 1, 6, 4, 4, 4, 1, 5, 1, 1, 2, 1, 6, 1,
#        1, 1, 5, 0, 2, 1, 6, 4, 4, 2, 2, 1, 1, 6, 1, 1, 4, 4, 2, 2, 1, 2,
#        1, 6, 4, 2, 0, 4, 5, 4, 3, 4, 0, 2, 4, 4, 1, 2, 4, 6, 2, 4, 0, 3,
#        6, 2, 6, 1, 6, 0, 2, 1], dtype=int32)

# %%
accuracy=model.score(x_test,y_test)

# %%
accuracy
# Out:
# -13080.092377656949
